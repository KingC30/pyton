# %%
"""
File:    pyopoly.py
Author:  Gia Bao Vo
Date:    10/26/20
Section: 31
E-mail:  giabaov1@umbc.edu
Description:
  This is the monopoly game it'sgonna buy and sell ur properties.
"""

# %%
def load_map(map_file_name):
    import csv
    try:
        with open(map_file_name) as map_file:
            reader = csv.DictReader(map_file, delimiter='\t')
            the_map = [dict(x) for x in reader]
            return the_map
    except OSError:
        print('Unable to find or open the file.')


def draw_in_block(block_num, side_length, the_grid, contents):
    if block_num in range(0, side_length):
        # along the bottom, gotta count up from the bottom by 3 rows
        starting_row = len(the_grid) - 3
        starting_col = len(the_grid[0]) - (block_num + 1) * 6
    elif block_num in range(side_length, 2 * side_length):
        starting_col = 1
        starting_row = len(the_grid) - 3 * ((block_num + 1) - side_length)
    elif block_num in range(2 * side_length, 3 * side_length):
        starting_row = 1
        starting_col = 6 * (block_num - 2 * side_length) + 1
    else:
        starting_col = len(the_grid[0]) - 6
        starting_row = 3 * (block_num - 3 * side_length) + 1

    split_contents = contents.split('\n')
    for row in range(2):
        for col in range(5):
            if col < len(split_contents[row]):
                the_grid[starting_row + row][starting_col + col] = split_contents[row][col]


def display_board(the_board):
    side_length = len(the_board) // 4 + 1
    grid = [['*' if (not (i % 6) or not (j % 3)) and ((0 <= i <= 6 or (side_length - 1) * 6 <= i) or (0 <= j <= 3 or (side_length - 1) * 3 <= j)) else " "
             for i in range(side_length * 6 + 1)] for j in range(side_length * 3 + 1)]

    for i, place in enumerate(the_board):
        draw_in_block(i, side_length - 1, grid, place)

    display_grid = '\n'.join([''.join(grid[i]) for i in range(3 * side_length + 1)])
    print(display_grid)

# %%
 """
File:    pyopoly.py
Author:  Gia Bao Vo
Date:    10/26/20
Section: 31
E-mail:  giabaov1@umbc.edu
Description:
  This is the monopoly game it'sgonna buy and sell ur properties.
"""

    
ABBREVIATED_NAME = 'Abbrev'
STARTING_MONEY = 1500
PASS_GO_MONEY = 200
FIRST_PLAYER_TURN = True
SECOND_PLAYER_TURN = False
PLAYER_NAME_INFO = 0
PLAYER_MONEY_INFO = 1
PLAYER_SYMBOL_INFO = 2
PLAYER_TURN_INFO = 3
PLAYER_ROLL_INFO = 4
PLAYER_POSITION_INFO = 5
PLAYER_LETTER_SYMBOL = 6
GAME_OVER = False
PLAYER_DICT = {}
ROLL_RESET = 0


    # put your header here
from sys import argv
from random import randint, seed
from board_methods import load_map, display_board
# possibly a lot more code here.  
# this code can be anywhere from right under the imports to right # above if __name__ == '__main__':
if len(argv) >= 2:
    seed(argv[1])

def play_game(starting_money, pass_go_money, board_file):
    balance = 0
    player1_info[balance] += 1500
    player2_info[balacne] += 1500
    
    Roll = randint(1,6) + randint(1,6)
    
    player1_info += roll
        
    player2_info

    
    
return

def take_turn(player, players, board):
    while player1_money > 0 and player2_money > 0:
        print ("Player" + player + "'s turn")
        Roll = randint(1,6) + randint(1,6)

        print("player moves")
        print("1) Buy Property\n
                2) Get Property Info\n
                3) Get Player Info\n
                4) Build a Building\n
                5) End Turn")
        choice = str(input(“enter 1-5”)
        if (choice == “1”):
            print("buy property")
            if location != owned:
                if price > 0:
                    if player money > price:
                        change owner pay price
                else:
                    price = -1
             # unauthorized says no breaks or exits though...
        if (choice == “2”):
            print("get property info")
            validProperty = false
            while validProperty == false:
                property = str(input("which property?"))
                if property in propertiesOnBoard:
                    validProperty = True
                    print(property_info)                
        if (choice == “3”):
            print("get player info")
            validUser = false
            while validUser == False:
                user = str(input("which user?"))
                if user in player1 or player2:
                    validUser = True
                    print(players)
        if (choice == “4”):
            print("build a building")
            if location != owned:
                if playerMoney > 0:
                    if building not in boardLocations:
                        building = true
        if (choice == “5”):
            print("end turn")

return
    
    
    

def format_display(players, board):
    player_dict = {}
    player1_info = []
    player1_name = input("What is your name?")
    player1_symbol = input("What is your symbol?").upper()

    player1_info.append(player1_name)
    player1_info.append(player1_symbol)

    player2_info = []
    player2_name = input("What is your name?")
    player2_symbol = input("What is your symbol?").upper()

    player2_info.append(player2_name)
    player2_info.append(player2_symbol)

    player_dict[player1_name] = player1_info
    player_dict[player2_name] = player2_info

    
    
    table = []
    for i in range(len(table)):
        first_half = board[i]['Abbrev'].ljust(5)
        table.append(first_half + "\n")
    display_board(table)

return

if __name__ == '__main__':
    file_name = input("what file are you trying to load? ")
    
    #if the file can't be found
    if load_map(file_name) == None:
        
        pass
    
    else:
        
        play_game(starting_MONEY, pass_go_money , file_name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-d3969847322f> in <module>
#      30 from sys import argv
#      31 from random import randint, seed
# ---> 32 from board_methods import load_map, display_board
#      33 # possibly a lot more code here.
#      34 # this code can be anywhere from right under the imports to right # above if __name__ == '__main__':
#
# ModuleNotFoundError: No module named 'board_methods'

# %%
from board_methods import load_map, display_board


QUIT_STRING = 'quit'

if __name__ == '__main__':
    for line in load_map('pyop3.csv'):
        print(line)

    the_board = []
    for i in range(8):
        the_board.append(
            input('What is the name of position {}? '.format(i))[0:5].ljust(5) + '\n     ')
        # the_board.append((str(i) * 5)[0:5] + '\n' + (str(i) * 5)[0:5])
        print(the_board[i])
        # format for display is this:
        # "xxxxx\nxxxxx"

    # ljust(5) pads your string with spaces to ensure it's length 5.
    display_board(the_board)

    print('hello world'.ljust(5))
    position = 0
    s = input('How many? ')
    while s != QUIT_STRING:
        position += int(s)
        position %= len(the_board)
        copy_board = list(the_board)
        copy_board[position] = copy_board[position][0:6] + "Play "
        display_board(copy_board)
        s = input('How many? ')

# %%
player_dict = {}
player1_info = []
player1_name = input("What is your name?") John
player1_symbol = input("What is your symbol?") J 

player1_info.append(player1_name)
player1_info.append(player1_symbol)

player2_info = []
player2_name = input("What is your name?") Bao
player2_symbol = input("What is your symbol?") B

player2_info.append(player2_name)
player2_info.append(player2_symbol)

player_dict[player1_name] = player1_info
player_dict[player2_name] = player2_info


print(player_dict) ==> {"John":["John", "J"], "Bao":["Bao", "B"]}

# %%
player_name = input("what is your name? ")
    player_symbol = string.upper(input("what is the symbol you want? "))
    
    player_dict = {}
    if player_name not in player_dict and player_symbol not in player_dict:
        player_dict['player 1'] = player_name
        player_dict['player 1'] = player_symbol

# %%
 """
File:    pyopoly.py
Author:  Gia Bao Vo
Date:    10/26/20
Section: 31
E-mail:  giabaov1@umbc.edu
Description:
  This is the monopoly game it'sgonna buy and sell ur properties.
"""


ABBREVIATED_NAME = 'Abbrev'
STARTING_FUNDS = 1500
PASS_GO_MONEY = 200
ROLL_RESET = 0
PLAYER_NAME_INFO = 0
PLAYER_SYMBOL_INFO = 1
PLAYER_TURN_INFO = 2
PLAYER_ROLL_INFO = 3
PLAYER_POSITION_INFO = 4
PLAYER_LETTER_SYMBOL = 5
PLAYER_MONEY_INFO = 6
FIRST_PLAYER_TURN = True
SECOND_PLAYER_TURN = False
GAME_OVER = False
END_TURN = False
PLAYERS_DICT = {}
OWNED_PROPERTY = {}


from sys import argv
from random import randint, seed
from board_methods import load_map, display_board
# possibly a lot more code here.  
# this code can be anywhere from right under the imports to right # above if __name__ == '__main__':
if len(argv) >= 2:
    seed(argv[1])

def play_game(starting_money, PASS_GO_MONEY, board_file):
    
    # loads the map returns a list
    the_board = load_map(board_file)

    # asks for user info and returns a dictionary
    PLAYERS_DICT = user_name_and_symbols()
    GAME_OVER = False
    # Game keeps going till it shouldn't anymore
    while GAME_OVER == False:

        # whos rolling 
        player_rolling = take_turn(PLAYERS_DICT,the_board)

        # rolls and stores roll and position to the players dict
        roll_dices(PLAYERS_DICT[player_rolling])

        format_display(PLAYERS_DICT, the_board)

        GAME_OVER = input("Roll Again? yes or no")
        
        

        after_roll(PLAYERS_DICT, player_rolling, the_board, OWNED_PROPERTY)
        
        while END_TURN == False:

            get_user_input(PLAYERS_DICT, player_rolling, the_board, OWNED_PROPERTY)


        player_moving_first = going_now(PLAYERS_DICT)
        player_moving_next = going_next(PLAYERS_DICT)

        next_turn(PLAYERS_DICT, player_moving_first, player_moving_next)

        if GAME_OVER != "no":
            GAME_OVER = False
        else:
            GAME_OVER = True
            
    who_lost(PLAYERS_DICT)



    pass


def get_user_input(PLAYERS_DICT, player, the_board, OWNED_PROPERTY):

    print()

    print("\t1) Buy Property")
    print("\t2) Get Property Info")
    print("\t3) Get Player Info")
    print("\t4) Build a Building ")
    print("\t5) End Turn")

    print()

    option_one = "1"
    option_two = "2"
    option_three = "3"
    option_four = "4"
    option_five = "5"

    buy_option = "buy property"
    get_property_info = "get property info"
    get_player_info = "get player info"
    build_option = "build a building"
    end_turn = 'end turn'
    error_validation = True

    user_input = input("\tWhat do you want to do?\n\t").lower()

    while error_validation != False:

        if user_input == option_one or user_input == buy_option:

            purchase_property(PLAYERS_DICT, player, the_board)
            error_validation = True

        if user_input == option_two or user_input == get_property_info:

            retrieve_property_info(OWNED_PROPERTY, the_board)
            error_validation = True
        
        if user_input == option_three or user_input == get_player_info:

            retrieve_player_info(PLAYERS_DICT, OWNED_PROPERTY)
            error_validation = True

        if user_input == option_four or user_input == build_option:

            building_price(PLAYERS_DICT, OWNED_PROPERTY, the_board, player)
            error_validation = True

        if user_input == option_five or user_input == end_turn:

            END_TURN = True
            error_validation = True

        else:

            error_validation = False
    pass
        
def purchase_property(PLAYERS_DICT, player, the_board):

    player_yes = "yes"
    player_y = 'y'
    board_place = "Place"
    board_price = "Price"
    building_built = False
    purchasable_price = 0

    players_position = PLAYERS_DICT[player][PLAYER_POSITION_INFO]
    property_stats = []
    board_property = the_board[players_position][board_place]

    if board_property not in OWNED_PROPERTY:

        want_to_buy = input("The property is unowned, do you want to buy it? ").lower()

        if want_to_buy == player_yes or want_to_buy == player_y:

            property_price = the_board[players_position][board_price]

            if int(property_price) >= purchasable_price:

                players_current_money = PLAYERS_DICT[player][PLAYER_MONEY_INFO]

                if players_current_money >= int(property_price):

                    new_balance = players_current_money - int(property_price)

                    PLAYERS_DICT[player][PLAYER_MONEY_INFO] = new_balance

                    print("You have bought {}".format(board_property))
                    property_stats.append(player)
                    property_stats.append(building_built)
                    OWNED_PROPERTY[board_property] = property_stats
                
                else:
                
                    print("You don't have enough money to buy {}".format(board_property))

            else:

                print("You cannot buy this property. It cannot be bought or sold.")
        
        else:

            print("You decided not to buy {}".format(board_property))
    
    else:
        owners_name = 0
        property_owner = OWNED_PROPERTY[board_property][owners_name]
        
        print("{} is the owner of the property. You cannot buy it.".format(property_owner))
        
    pass

    
def retrieve_property_info(OWNED_PROPERTY, the_board):

    what_property = input("For which property do you want to get the information? ")

    building_price = "Price"
    building_name = "Place"
    building_abbrev = "Abbrev"
    place_rent = "Rent"
    building_rent = "BuildingRent"
    for i in range(len(the_board)):

        if what_property == the_board[i][building_name] or what_property == the_board[i][building_abbrev]:
            owned_buildings = {}
            building_exist = "No"
            for dicts in the_board:
                for keys in dicts:
                    if keys == building_name:
                        if dicts[building_name] not in owned_buildings:
                            owned_buildings[dicts[building_name]] = building_exist

            for dicts in the_board:
                for keys in dicts:  
                    if what_property == dicts[building_name] or what_property == dicts[building_abbrev]:
                        if keys == building_name:
                            bank_or_player = "BANK"
                            building_real_name = dicts[keys]
                            if dicts[keys] in OWNED_PROPERTY:
                                owner_ship = 0
                                bank_or_player = OWNED_PROPERTY[keys][owner_ship]

                        if keys == building_price:
                            building_price = "No"
                            cannot_buy = "-1"

                            if dicts[keys] != cannot_buy:
                                building_price = dicts[keys]
                            else:
                                building_price = cannot_buy

                        if keys == place_rent:
                            the_rent = dicts[keys]

                        if keys == building_rent:
                            the_building_rent = dicts[keys]
                    
            building_exist = owned_buildings[building_real_name]

            print()
            print("\t{}".format(building_real_name))
            print("\tPrice: {}".format(building_price))
            print("\tOwner: {}".format(bank_or_player))
            print("\tBuilding: {}".format(building_exist))
            print("\tRent {}, {} (with building)".format(the_rent, the_building_rent))
            print()
            print()

    pass


def retrieve_player_info(PLAYERS_DICT, OWNED_PROPERTY):

    player_names = get_player_names(PLAYERS_DICT)
    player_one = 0
    player_two = 1
    print("The players are:\n\t\t{}\n\t\t{}".format(player_names[player_one], player_names[player_two]))
    what_player = input("Which player do you wish to know about? ")

    if what_player in PLAYERS_DICT:

        print()
        print(PLAYERS_DICT[what_player][PLAYER_NAME_INFO])
        print(PLAYERS_DICT[what_player][PLAYER_SYMBOL_INFO])
        print("Current Money: {}".format(PLAYERS_DICT[what_player][PLAYER_MONEY_INFO]))
        print()
        print("Properties Owned:")
        print()
        for buildings in OWNED_PROPERTY:
            owner_ship = 0
            built_building = 1
            if OWNED_PROPERTY[buildings][owner_ship] == what_player:
                print("\t\t{} with a building: {}".format(buildings, OWNED_PROPERTY[buildings][built_building]))
        no_property = 0
        if len(OWNED_PROPERTY) == no_property:
            print("\t\tNo Properties Yet")
    pass


def building_price(PLAYERS_DICT, OWNED_PROPERTY, the_board, player):

    building_status = 1
    building_name = "Place"
    building_abbrev = "Abbrev"
    building_cost = "BuildingCost"
    building_owner = 0
    build_able = True

    for buildings in OWNED_PROPERTY:
        for dicts in the_board:
            if OWNED_PROPERTY[buildings][building_status] == False and dicts[keys] in OWNED_PROPERTY:
                for keys in dicts:
                    if keys == building_name:
                        building_name = dicts[keys]
                    if keys == building_abbrev:
                        building_abbrev = dicts[keys]
                    if keys == building_cost:
                        building_cost = dicts[keys]
                    
        print("{} {} {}".format(building_name, building_abbrev, building_cost))
    
    build_what = input("Which property do you want to build a building on? ")
   
    for i in range(len(the_board)):
        if build_what == the_board[i][building_name] or build_what == dicts[i][building_abbrev]:
            build_what = the_board[i][building_name]
            building_cost = the_board[i][building_cost]

    for i in range(len(the_board)):
    
        if build_what not in the_board[i][building_name] or build_what not in the_board[i][building_abbrev] \
            or player != OWNED_PROPERTY[building_name][building_owner]:
            can_build_or_no = "The property either has a building, isn't yours, or doesn't exist"
            build_able = False
    
    if build_able == False:  
        print(can_build_or_no)

    if build_able == True:

        current_money = PLAYERS_DICT[player][PLAYER_MONEY_INFO]
        
        new_money = current_money - building_cost

        PLAYERS_DICT[player][PLAYER_MONEY_INFO] = new_money
        calculate_rents(PLAYERS_DICT, player, the_board)

    pass


def take_turn(PLAYERS_DICT, the_board):

    player_moving_first = going_now(PLAYERS_DICT)


    # might need to do if statement for later on but for now this should work ?

    return player_moving_first

    
def format_display(PLAYERS_DICT, the_board):

    game_board = []

    for line in the_board:

        game_board.append((line[ABBREVIATED_NAME].ljust(5) + '\n     '))

    player_moving_first = going_now(PLAYERS_DICT)
    player_moving_next = going_next(PLAYERS_DICT)    

    player1_position = ((PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO]) \
        % (len(the_board)))
    player2_position = ((PLAYERS_DICT[player_moving_next][PLAYER_POSITION_INFO]) \
        % (len(the_board)))

    pass_go_money(PLAYERS_DICT, player_moving_first, the_board)

    PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO] = player1_position

    first_symbol = PLAYERS_DICT[player_moving_first][PLAYER_LETTER_SYMBOL]
    second_symbol = PLAYERS_DICT[player_moving_next][PLAYER_LETTER_SYMBOL]

    copy_board1 = list(game_board)
    copy_board2 = copy_board1

    if player1_position != player2_position:
        zero = 0
        five = 5
        copy_board1[player1_position] = copy_board1[player1_position][zero:five] \
            + '\n{}    '.format(first_symbol)
        copy_board2[player2_position] = copy_board2[player2_position][zero:five] \
            + '\n{}    '.format(second_symbol)

        display_board(copy_board2)

    else:

        # if players land on the same location 
        copy_board1[player1_position] = copy_board1[player1_position][zero:five] \
            + '\n{}{}   '.format(first_symbol, second_symbol)
        copy_board2[player2_position] = copy_board2[player2_position][zero:five] \
            + '\n{}{}   '.format(first_symbol, second_symbol)
        
        display_board(copy_board2)

    pass


def next_turn(PLAYERS_DICT, player_moving_first, player_moving_next):

    PLAYERS_DICT[player_moving_first][PLAYER_TURN_INFO] = False
    PLAYERS_DICT[player_moving_next][PLAYER_TURN_INFO] = True

    PLAYERS_DICT[player_moving_first][PLAYER_ROLL_INFO] = ROLL_RESET
    PLAYERS_DICT[player_moving_next][PLAYER_ROLL_INFO] = ROLL_RESET

    END_TURN = False

    pass


def user_name_and_symbols():

    first_player = input("First player, what is your name? ")
    first_symbol = input("First player, what symbol do you want your character to use? ").upper()

    empty_input = ""
    while first_symbol == empty_input:

        first_symbol = input("First player, what symbol do you want your character to use? ")

    while len(first_symbol) > 1:

        print("Symbol should only be one capital letter")

        first_symbol = input("First player, what symbol do you want your character to use? ")

    second_player = input("Second player, what is your name? ")

    while first_player.lower() == second_player.lower():

        print("Names should not be the same.")

        second_player = input("Second player, what is your name? ")

    second_symbol = input("Second player, what symbol do you want your character to use? ").upper()

    while second_symbol == empty_input:

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    while second_symbol == first_symbol:

        print("Symbol {} has already been used.".format(second_symbol))

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    while second_symbol == first_symbol.lower():

        print("Symbol {} has already been used.".format(second_symbol))

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    while len(second_symbol) > 1:

        print("Symbol should only be one capital letter")

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    player1_name = "Player Name: {}".format(first_player)

    player1_symbol = "Player Symbol: {}".format(first_symbol)

    player1_roll = 0
    player1_position = 0

    player1_info = []

    player1_info.append(player1_name)
    player1_info.append(player1_symbol)
    player1_info.append(FIRST_PLAYER_TURN)
    player1_info.append(player1_roll)
    player1_info.append(player1_position)
    player1_info.append(first_symbol)
    player1_info.append(STARTING_FUNDS)

    player2_name = "Player Name: {}".format(second_player)

    player2_symbol = "Player Symbol: {}".format(second_symbol)

    player2_roll = 0 
    player2_position = 0

    player2_info = []

    player2_info.append(player2_name)
    player2_info.append(player2_symbol)
    player2_info.append(SECOND_PLAYER_TURN)
    player2_info.append(player2_roll)
    player2_info.append(player2_position)
    player2_info.append(second_symbol)
    player2_info.append(STARTING_FUNDS)

    PLAYERS_DICT[first_player] = player1_info
    PLAYERS_DICT[second_player] = player2_info

    return PLAYERS_DICT


def pass_go_money(PLAYERS_DICT, player, the_board):

    player_moving_first = going_now(PLAYERS_DICT) 
    player1_position = ((PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO]) % (len(the_board)))
    starting_position = 0
    current_cash = PLAYERS_DICT[player][PLAYER_MONEY_INFO]
    if player1_position < (PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO]) \
         and (PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO] != starting_position):
         
        PLAYERS_DICT[player][PLAYER_MONEY_INFO] = (current_cash + PASS_GO_MONEY)


def calculate_rents(PLAYERS_DICT, player, the_board):

    current_cash = PLAYERS_DICT[player][PLAYER_MONEY_INFO]
    
    if current_cash < 0:
        GAME_OVER = True

    pass
    
def who_lost(PLAYERS_DICT):
    pass

def after_roll(PLAYERS_DICT, player, the_board, OWNED_PROPERTY):

    roll_count = PLAYERS_DICT[player][PLAYER_ROLL_INFO]
    player_location = PLAYERS_DICT[player][PLAYER_POSITION_INFO]
    building_built = 1
    building_rent = "BuildingRent"
    board_place = "Place"
    board_position = "Position"
    regular_rent = "Rent"
    current_location = the_board[player_location][board_place]

    print("{} you have rolled {}".format(player, roll_count))
    print("{} you landed on {}".format(player, current_location))
    
    player_position = PLAYERS_DICT[player][PLAYER_POSITION_INFO]

    for i in range(len(the_board)):
        if the_board[i][board_position] == player_position:
            
            player_lands_on = the_board[i][board_place]
            regular_rent = the_board[i][regular_rent]
            building_rent = the_board[i][building_built]

    owners_name = 0

    if player_lands_on in OWNED_PROPERTY:

        property_owner = OWNED_PROPERTY[player_lands_on][owners_name]
        print("You landed on {}'s property, you must pay the rent.".format(property_owner))
       
        if OWNED_PROPERTY[player_lands_on][building_built] == False:
            
            print("You have paid {} to {}".format(regular_rent, property_owner))

        if OWNED_PROPERTY[player_lands_on][building_built] == True:

            print("You have paid {} to {}".format(building_rent, property_owner))

    calculate_rents(PLAYERS_DICT, player, the_board)


def roll_dices(players_list):

    player_roll = 0
    
    player_roll = (randint(1,6) + randint(1,6))

    roll_count = ((players_list[PLAYER_ROLL_INFO]) + player_roll)
    position_count = ((players_list[PLAYER_POSITION_INFO]) + player_roll)

    players_list[PLAYER_ROLL_INFO] = roll_count
    players_list[PLAYER_POSITION_INFO] = position_count

    pass


def going_now(PLAYERS_DICT):

    for key in PLAYERS_DICT:

        if PLAYERS_DICT[key][PLAYER_TURN_INFO] == True:

            the_key = key

            return the_key

        
def going_next(PLAYERS_DICT):

    for key in PLAYERS_DICT:

        if PLAYERS_DICT[key][PLAYER_TURN_INFO] == False:

            the_key = key

            return the_key

def get_player_names(PLAYERS_DICT):

    players_names = []

    for keys in PLAYERS_DICT:

        players_names.append(keys)
    
    return players_names


if __name__ == '__main__':

   # asks the user what board file they want to use
   file_name = input("What file would you like to load? ")

   # if the board_name_file isnt found
   if load_map(file_name) == None:
      
      # place holder
    pass

   else:
       
       play_game(STARTING_FUNDS, PASS_GO_MONEY, file_name)

# %%
ABBREVIATED_NAME = 'Abbrev'
STARTING_FUNDS = 1500
PASS_GO_MONEY = 200
ROLL_RESET = 0
PLAYER_NAME_INFO = 0
PLAYER_SYMBOL_INFO = 1
PLAYER_TURN_INFO = 2
PLAYER_ROLL_INFO = 3
PLAYER_POSITION_INFO = 4
PLAYER_LETTER_SYMBOL = 5
PLAYER_MONEY_INFO = 6
FIRST_PLAYER_TURN = True
SECOND_PLAYER_TURN = False
GAME_OVER = False
END_TURN = False
PLAYERS_DICT = {}
OWNED_PROPERTY = {}


from sys import argv
from random import randint, seed
from board_methods import load_map, display_board
# possibly a lot more code here.  
# this code can be anywhere from right under the imports to right # above if __name__ == '__main__':
if len(argv) >= 2:
    seed(argv[1])

def play_game(starting_money, PASS_GO_MONEY, board_file):
    
    # loads the map returns a list
    the_board = load_map(board_file)

    # asks for user info and returns a dictionary
    PLAYERS_DICT = user_name_and_symbols()
    GAME_OVER = False
    # Game keeps going till it shouldn't anymore
    while GAME_OVER == False:

        # whos rolling 
        player_rolling = take_turn(PLAYERS_DICT,the_board)

        # rolls and stores roll and position to the players dict
        roll_dices(PLAYERS_DICT[player_rolling])

        format_display(PLAYERS_DICT, the_board)

        GAME_OVER = input("Roll Again? yes or no")
        
        

        after_roll(PLAYERS_DICT, player_rolling, the_board, OWNED_PROPERTY)
        
        while END_TURN == False:

            get_user_input(PLAYERS_DICT, player_rolling, the_board, OWNED_PROPERTY)


        player_moving_first = current_player(PLAYERS_DICT)
        player_moving_next = next_player(PLAYERS_DICT)

        next_turn(PLAYERS_DICT, player_moving_first, player_moving_next)

        if GAME_OVER != "no":
            GAME_OVER = False
        else:
            GAME_OVER = True
            
    who_lost(PLAYERS_DICT)



    pass


def get_user_input(PLAYERS_DICT, player, the_board, OWNED_PROPERTY):

    print()

    print("\t1) Buy Property")
    print("\t2) Get Property Info")
    print("\t3) Get Player Info")
    print("\t4) Build a Building ")
    print("\t5) End Turn")

    print()

    first_option = "1"
    second_option = "2"
    third_option = "3"
    fourth_option = "4"
    fifth_option = "5"

    buy = "Buy Property"
    get_property_info = "Get Property Info"
    get_player_info = "Get Player Info"
    build_option = "Build a Building"
    end_turn = 'End Turn'
    error_validation = True

    user_input = input("\tWhat would you like to do?\n\t").lower()

    while error_validation != False:

        if user_input == first_option or user_input == buy:

            purchase_property(PLAYERS_DICT, player, the_board)
            error_validation = True

        if user_input == second_option or user_input == get_property_info:

            retrieve_property_info(OWNED_PROPERTY, the_board)
            error_validation = True
        
        if user_input == third_option or user_input == get_player_info:

            retrieve_player_info(PLAYERS_DICT, OWNED_PROPERTY)
            error_validation = True

        if user_input == fourth_option or user_input == build_option:

            building_price(PLAYERS_DICT, OWNED_PROPERTY, the_board, player)
            error_validation = True

        if user_input == fifth_option or user_input == end_turn:

            #END_TURN = True
            error_validation = True

        else:

            error_validation = False
    pass
        
def purchase_property(PLAYERS_DICT, player, the_board):

    player_yes = "yes"
    player_y = 'y'
    board_place = "Place"
    board_price = "Price"
    building_built = False
    purchasable_price = 0

    players_position = PLAYERS_DICT[player][PLAYER_POSITION_INFO]
    property_stats = []
    board_property = the_board[players_position][board_place]

    if board_property not in OWNED_PROPERTY:

        want_to_buy = input("The property is unowned, do you want to buy it? ").lower()

        if want_to_buy == player_yes or want_to_buy == player_y:

            property_price = the_board[players_position][board_price]

            if int(property_price) >= purchasable_price:

                players_current_money = PLAYERS_DICT[player][PLAYER_MONEY_INFO]

                if players_current_money >= int(property_price):

                    new_balance = players_current_money - int(property_price)

                    PLAYERS_DICT[player][PLAYER_MONEY_INFO] = new_balance

                    print("You have bought {}".format(board_property))
                    property_stats.append(player)
                    property_stats.append(building_built)
                    OWNED_PROPERTY[board_property] = property_stats
                
                else:
                
                    print("You don't have enough money to buy {}".format(board_property))

            else:

                print("You cannot buy this property. It cannot be bought or sold.")
        
        else:

            print("You decided not to buy {}".format(board_property))
    
    else:
        owners_name = 0
        property_owner = OWNED_PROPERTY[board_property][owners_name]
        
        print("{} is the owner of the property. You cannot buy it.".format(property_owner))
        
    pass

    
def retrieve_property_info(OWNED_PROPERTY, the_board):

    what_property = input("For which property do you want to get the information? ")

    building_price = "Price"
    building_name = "Place"
    building_abbrev = "Abbrev"
    place_rent = "Rent"
    building_rent = "BuildingRent"
    for i in range(len(the_board)):

        if what_property == the_board[i][building_name] or what_property == the_board[i][building_abbrev]:
            owned_buildings = {}
            building_exist = "No"
            for dicts in the_board:
                for keys in dicts:
                    if keys == building_name:
                        if dicts[building_name] not in owned_buildings:
                            owned_buildings[dicts[building_name]] = building_exist

            for dicts in the_board:
                for keys in dicts:  
                    if what_property == dicts[building_name] or what_property == dicts[building_abbrev]:
                        if keys == building_name:
                            bank_or_player = "BANK"
                            building_real_name = dicts[keys]
                            if dicts[keys] in OWNED_PROPERTY:
                                owner_ship = 0
                                bank_or_player = OWNED_PROPERTY[keys][owner_ship]

                        if keys == building_price:
                            building_price = "No"
                            cannot_buy = "-1"

                            if dicts[keys] != cannot_buy:
                                building_price = dicts[keys]
                            else:
                                building_price = cannot_buy

                        if keys == place_rent:
                            the_rent = dicts[keys]

                        if keys == building_rent:
                            the_building_rent = dicts[keys]
                    
            building_exist = owned_buildings[building_real_name]

            print()
            print("\t{}".format(building_real_name))
            print("\tPrice: {}".format(building_price))
            print("\tOwner: {}".format(bank_or_player))
            print("\tBuilding: {}".format(building_exist))
            print("\tRent {}, {} (with building)".format(the_rent, the_building_rent))
            print()
            print()

    pass


def retrieve_player_info(PLAYERS_DICT, OWNED_PROPERTY):

    player_names = get_player_names(PLAYERS_DICT)
    player_one = 0
    player_two = 1
    print("The players are:\n\t\t{}\n\t\t{}".format(player_names[player_one], player_names[player_two]))
    what_player = input("Which player do you wish to know about? ")

    if what_player in PLAYERS_DICT:

        print()
        print(PLAYERS_DICT[what_player][PLAYER_NAME_INFO])
        print(PLAYERS_DICT[what_player][PLAYER_SYMBOL_INFO])
        print("Current Money: {}".format(PLAYERS_DICT[what_player][PLAYER_MONEY_INFO]))
        print()
        print("Properties Owned:")
        print()
        for buildings in OWNED_PROPERTY:
            owner_ship = 0
            built_building = 1
            if OWNED_PROPERTY[buildings][owner_ship] == what_player:
                print("\t\t{} with a building: {}".format(buildings, OWNED_PROPERTY[buildings][built_building]))
        no_property = 0
        if len(OWNED_PROPERTY) == no_property:
            print("\t\tNo Properties Yet")
    pass


def building_price(PLAYERS_DICT, OWNED_PROPERTY, the_board, player):

    building_status = 1
    building_name = "Place"
    building_abbrev = "Abbrev"
    building_cost = "BuildingCost"
    building_owner = 0
    build_able = True

    for buildings in OWNED_PROPERTY:
        for dicts in the_board:
          #if OWNED_PROPERTY[buildings][building_status] == False and dicts[keys] in OWNED_PROPERTY:
          for keys in dicts:
            if OWNED_PROPERTY[buildings][building_status] == False and dicts[keys] in OWNED_PROPERTY:
              if keys == building_name:
                  building_name = dicts[keys]
              if keys == building_abbrev:
                  building_abbrev = dicts[keys]
              if keys == building_cost:
                  building_cost = dicts[keys]
                    
        print("{} {} {}".format(building_name, building_abbrev, building_cost))
    
    build_what = input("Which property do you want to build a building on? ")
   
    for i in range(len(the_board)):
        if build_what == the_board[i][building_name] or build_what == dicts[i][building_abbrev]:
            build_what = the_board[i][building_name]
            building_cost = the_board[i][building_cost]

    for i in range(len(the_board)):
    
        if build_what not in the_board[i][building_name] or build_what not in the_board[i][building_abbrev] \
            or player != OWNED_PROPERTY[building_name][building_owner]:
            can_build_or_no = "The property either has a building, isn't yours, or doesn't exist"
            build_able = False
    
    if build_able == False:  
        print(can_build_or_no)

    if build_able == True:

        current_money = PLAYERS_DICT[player][PLAYER_MONEY_INFO]
        
        new_money = current_money - building_cost

        PLAYERS_DICT[player][PLAYER_MONEY_INFO] = new_money
        calculate_rents(PLAYERS_DICT, player, the_board)

    pass


def take_turn(PLAYERS_DICT, the_board):

    player_moving_first = current_player(PLAYERS_DICT)


    # might need to do if statement for later on but for now this should work ?

    return player_moving_first

    
def format_display(PLAYERS_DICT, the_board):

    game_board = []

    for line in the_board:

        game_board.append((line[ABBREVIATED_NAME].ljust(5) + '\n     '))

    player_moving_first = current_player(PLAYERS_DICT)
    player_moving_next = next_player(PLAYERS_DICT)    

    player1_position = ((PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO]) \
        % (len(the_board)))
    player2_position = ((PLAYERS_DICT[player_moving_next][PLAYER_POSITION_INFO]) \
        % (len(the_board)))

    pass_go_money(PLAYERS_DICT, player_moving_first, the_board)

    PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO] = player1_position

    first_symbol = PLAYERS_DICT[player_moving_first][PLAYER_LETTER_SYMBOL]
    second_symbol = PLAYERS_DICT[player_moving_next][PLAYER_LETTER_SYMBOL]

    board_duplicate1 = list(game_board)
    board_duplicate2 = board_duplicate1

    if player1_position != player2_position:
        zero = 0
        five = 5
        board_duplicate1[player1_position] = board_duplicate1[player1_position][zero:five] \
            + '\n{}    '.format(first_symbol)
        board_duplicate2[player2_position] = board_duplicate2[player2_position][zero:five] \
            + '\n{}    '.format(second_symbol)

        display_board(board_duplicate2)

    else:

        # if players land on the same location 
        board_duplicate1[player1_position] = board_duplicate1[player1_position][zero:five] \
            + '\n{}{}   '.format(first_symbol, second_symbol)
        board_duplicate2[player2_position] = board_duplicate2[player2_position][zero:five] \
            + '\n{}{}   '.format(first_symbol, second_symbol)
        
        display_board(board_duplicate2)

    pass


def next_turn(PLAYERS_DICT, player_moving_first, player_moving_next, END_TURN):

    PLAYERS_DICT[player_moving_first][PLAYER_TURN_INFO] = False
    PLAYERS_DICT[player_moving_next][PLAYER_TURN_INFO] = True

    PLAYERS_DICT[player_moving_first][PLAYER_ROLL_INFO] = ROLL_RESET
    PLAYERS_DICT[player_moving_next][PLAYER_ROLL_INFO] = ROLL_RESET

    END_TURN = False
    return END_TURN
    pass


def user_name_and_symbols():

    first_player = input("First player, what is your name? ")
    first_symbol = input("First player, what symbol do you want your character to use? ").upper()

    empty_input = ""
    while first_symbol == empty_input:

        first_symbol = input("First player, what symbol do you want your character to use? ")

    while len(first_symbol) > 1:

        print("Symbol should only be one capital letter")

        first_symbol = input("First player, what symbol do you want your character to use? ")

    second_player = input("Second player, what is your name? ")

    while first_player.lower() == second_player.lower():

        print("Names should not be the same.")

        second_player = input("Second player, what is your name? ")

    second_symbol = input("Second player, what symbol do you want your character to use? ").upper()

    while second_symbol == empty_input:

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    while second_symbol == first_symbol:

        print("Symbol {} has already been used.".format(second_symbol))

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    while second_symbol == first_symbol.lower():

        print("Symbol {} has already been used.".format(second_symbol))

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    while len(second_symbol) > 1:

        print("Symbol should only be one capital letter")

        second_symbol = input("Second player, what symbol do you want your character to use? ")

    player1_name = "Player Name: {}".format(first_player)

    player1_symbol = "Player Symbol: {}".format(first_symbol)

    player1_roll = 0
    player1_position = 0

    player1_info = []

    player1_info.append(player1_name)
    player1_info.append(player1_symbol)
    player1_info.append(FIRST_PLAYER_TURN)
    player1_info.append(player1_roll)
    player1_info.append(player1_position)
    player1_info.append(first_symbol)
    player1_info.append(STARTING_FUNDS)

    player2_name = "Player Name: {}".format(second_player)

    player2_symbol = "Player Symbol: {}".format(second_symbol)

    player2_roll = 0 
    player2_position = 0

    player2_info = []

    player2_info.append(player2_name)
    player2_info.append(player2_symbol)
    player2_info.append(SECOND_PLAYER_TURN)
    player2_info.append(player2_roll)
    player2_info.append(player2_position)
    player2_info.append(second_symbol)
    player2_info.append(STARTING_FUNDS)

    PLAYERS_DICT[first_player] = player1_info
    PLAYERS_DICT[second_player] = player2_info

    return PLAYERS_DICT


def pass_go_money(PLAYERS_DICT, player, the_board):

    player_moving_first = current_player(PLAYERS_DICT) 
    player1_position = ((PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO]) % (len(the_board)))
    starting_position = 0
    current_cash = PLAYERS_DICT[player][PLAYER_MONEY_INFO]
    if player1_position < (PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO]) \
         and (PLAYERS_DICT[player_moving_first][PLAYER_POSITION_INFO] != starting_position):
         
        PLAYERS_DICT[player][PLAYER_MONEY_INFO] = (current_cash + PASS_GO_MONEY)


def calculate_rents(PLAYERS_DICT, player, the_board, GAME_OVER):

    current_cash = PLAYERS_DICT[player][PLAYER_MONEY_INFO]
    
    if current_cash < 0:
        GAME_OVER = True
    return GAME_OVER
    pass
    
def who_lost(PLAYERS_DICT):
    pass

def after_roll(PLAYERS_DICT, player, the_board, OWNED_PROPERTY):

    roll_count = PLAYERS_DICT[player][PLAYER_ROLL_INFO]
    player_location = PLAYERS_DICT[player][PLAYER_POSITION_INFO]
    building_built = 1
    building_rent = "BuildingRent"
    board_place = "Place"
    board_position = "Position"
    regular_rent = "Rent"
    current_location = the_board[player_location][board_place]

    print("{} you have rolled {}".format(player, roll_count))
    print("{} you landed on {}".format(player, current_location))
    
    player_position = PLAYERS_DICT[player][PLAYER_POSITION_INFO]

    player_move_to = the_board[player_location][board_place]


    for i in range(len(the_board)):
        if the_board[i][board_position] == player_position:
            
            player_move_to = the_board[i][board_place]
            regular_rent = the_board[i][regular_rent]
            building_rent = the_board[i][building_built]

    owners_name = 0

    if player_move_to in OWNED_PROPERTY:

        property_owner = OWNED_PROPERTY[player_move_to][owners_name]
        print("You landed on {}'s property, you must pay the rent.".format(property_owner))
       
        if OWNED_PROPERTY[player_move_to][building_built] == False:
            
            print("You have paid {} to {}".format(regular_rent, property_owner))

        if OWNED_PROPERTY[player_move_to][building_built] == True:

            print("You have paid {} to {}".format(building_rent, property_owner))

    calculate_rents(PLAYERS_DICT, player, the_board)


def roll_dices(players_list):

    roll = 0
    
    roll = (randint(1,6) + randint(1,6))

    roll_count = ((players_list[PLAYER_ROLL_INFO]) + roll)
    position_count = ((players_list[PLAYER_POSITION_INFO]) + roll)

    players_list[PLAYER_ROLL_INFO] = roll_count
    players_list[PLAYER_POSITION_INFO] = position_count

    pass


def current_player(PLAYERS_DICT):

    for key in PLAYERS_DICT:

        if PLAYERS_DICT[key][PLAYER_TURN_INFO] == True:

            main_key = key

            return main_key

        
def next_player(PLAYERS_DICT):

    for key in PLAYERS_DICT:

        if PLAYERS_DICT[key][PLAYER_TURN_INFO] == False:

            the_key = key

            return the_key

def get_player_names(PLAYERS_DICT):

    names_of_players = []

    for keys in PLAYERS_DICT:

        names_of_players.append(keys)
    
    return names_of_players


if __name__ == '__main__':

   # asks the user what board file they want to use
   file_name = input("What file would you like to load? ")

   # if the board_name_file isnt found
   if load_map(file_name) == None:
      
      # place holder
    pass

   else:
       
       play_game(STARTING_FUNDS, PASS_GO_MONEY, file_name)
